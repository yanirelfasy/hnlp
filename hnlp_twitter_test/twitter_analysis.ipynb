# %%
import tweepy
import pandas as pd
import csv
import re 
import string
import preprocessor as p
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
from collections import  Counter
import emoji
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import SGDClassifier
np.random.seed(42)

# %% [markdown]
# # Init general parameters

# %%
consumer_key="18GgtxgXKtFNClpxb7iore84G"
consumer_secret="RzqoSkUi5919JWYY2hew6WpTtEXah2PJLOvDwkMFlJfcpS9lgO"
access_token_key="1393585869026697216-HYA8QxK0ShrF9r1mUwzyfm1mqm5Imn"
access_token_secret="h4fVbzG4SgK8yqAL6d18QP4IEEvLyuevEashyprrkfdAp"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token_key, access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True)

# %%
user_ids = ["netanyahu", "meravmichaelijs", "naftalibennett", "tamarzandberg", "yairlapid", "ayelet__shaked", "AvigdorLiberman", "regev_miri", "NitzanHorowitz"]

# %% [markdown]
# # Pull data from twitter - run in order to pull new data

# %%
data_per_user = dict()
last_id_per_user = dict()
for user_id in user_ids:
    last_id_per_user[user_id] = -1
    data_per_user[user_id] = []
for user_id in user_ids:
    print("WORKING ON " + user_id)
    last_id = None
    while len(data_per_user[user_id]) < 1:
        if last_id_per_user[user_id] != -1:
            last_id = last_id_per_user[user_id]
        tweets = api.user_timeline(screen_name=user_id, count=200, include_rts = False, exclude_replies=True, tweet_mode = 'extended', max_id = last_id)
        pulled_data = [[tweet.id_str, tweet.created_at, tweet.favorite_count, tweet.retweet_count, tweet.full_text.encode("utf-8").decode("utf-8")] for idx,tweet in enumerate(tweets)]
        data_per_user[user_id].extend(pulled_data)
        if len(tweets) == 0:
                break
        last_id_per_user[user_id] = tweets[-1].id
    print("DONE WITH " + user_id)
# Out:
# WORKING ON netanyahu
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-1fe7c9fb4514> in <module>
#      10         if last_id_per_user[user_id] != -1:
#      11             last_id = last_id_per_user[user_id]
# ---> 12         tweets = api.user_timeline(screen_name=user_id, count=200, include_rts = False, exclude_replies=True, tweet_mode = 'extended', max_id = last_id)
#      13         pulled_data = [[tweet.id_str, tweet.created_at, tweet.favorite_count, tweet.retweet_count, tweet.full_text.encode("utf-8").decode("utf-8")] for idx,tweet in enumerate(tweets)]
#      14         data_per_user[user_id].extend(pulled_data)
#
# NameError: name 'api' is not defined

# %% [markdown]
# # Read local data

# %%
for user_id in user_ids:
    df = pd.DataFrame(data_per_user[user_id], columns=["id","created_at","favorite_count","retweet_count", "text"])
    df.to_csv('Data/%s_tweets.csv' % user_id,index=False)

# %% [markdown]
# # Data Processing

# %% [markdown]
# ## Data Preview

# %%
all_data = pd.DataFrame(columns=["id", "text", "label"])
for user_id in user_ids:
    raw_data = pd.read_csv('%s_tweets.csv' % user_id)
    raw_data["label"] = user_id
    row = raw_data[["id", "text", "label"]]
    all_data = all_data.append(row)
print(all_data)
# Out:
#                        id                                               text  \
# 0     1400120105783152647  עוד פרטים: https://t.co/rrKuyf4nnA https://t.c...
# 1     1400025751848632321  אני מברך את יצחק הרצוג על בחירתו לנשיא המדינה ...
# 2     1399768934337945601  הטענה המרכזית בתיק התפור 4000 - קרסה היום בבית...
# 3     1399679823786696707  האיום הגדול ביותר עלינו זה האיום הקיומי שמוצב ...
# 4     1399670824064462854  למוסד יצא בצדק רב מוניטין של אחד מארגוני הביון...
# ...                   ...                                                ...
# 2235   886622894738079744  התנגדות המדינה לאימוץ ע״י הורים להטבים מראה שה...
# 2236   886279548807110657  עכשיו גם בתל אביב. עדיין רחוק מאוד מהמספרים של...
# 2237   885065513096839169  קצת הדתה להיום:\r\nאיכה היתה לזונה קריה נאמנה,...
# 2238   884683576662536192  ״ממשלת החלומות של החרדים״ הגדיר את זה @yairche...
# 2239   884490381194297344  כוכב הערב - הבן של גבאי. ״אבא יעשה שלטון סוציא...
#
#                label
# 0          netanyahu
# 1          netanyahu
# 2          netanyahu
# 3          netanyahu
# 4          netanyahu
# ...              ...
# 2235  NitzanHorowitz
# 2236  NitzanHorowitz
# 2237  NitzanHorowitz
# 2238  NitzanHorowitz
# 2239  NitzanHorowitz
#
# [20233 rows x 3 columns]

# %% [markdown]
# ## Remove all tweets that are not including hebrew letters

# %%
def is_tweet_has_hebrew(text):
    return any("\u0590" <= c <= "\u05EA" for c in text)

non_hebrew = []
hebrew_only = pd.DataFrame(columns=["id", "text", "label"])
for idx, row in all_data.iterrows():
    if not is_tweet_has_hebrew(row["text"]):
        non_hebrew.append(row["text"])
    else:
        row["text"] = row["text"].replace(".", "")
        hebrew_only = hebrew_only.append(row)
print(len(non_hebrew))
print(hebrew_only)
# Out:
# 934
#                        id                                               text  \
# 0     1400120105783152647  עוד פרטים: https://tco/rrKuyf4nnA https://tco/...
# 1     1400025751848632321  אני מברך את יצחק הרצוג על בחירתו לנשיא המדינה ...
# 2     1399768934337945601  הטענה המרכזית בתיק התפור 4000 - קרסה היום בבית...
# 3     1399679823786696707  האיום הגדול ביותר עלינו זה האיום הקיומי שמוצב ...
# 4     1399670824064462854  למוסד יצא בצדק רב מוניטין של אחד מארגוני הביון...
# ...                   ...                                                ...
# 2235   886622894738079744  התנגדות המדינה לאימוץ ע״י הורים להטבים מראה שה...
# 2236   886279548807110657  עכשיו גם בתל אביב עדיין רחוק מאוד מהמספרים של ...
# 2237   885065513096839169  קצת הדתה להיום:\r\nאיכה היתה לזונה קריה נאמנה,...
# 2238   884683576662536192  ״ממשלת החלומות של החרדים״ הגדיר את זה @yairche...
# 2239   884490381194297344  כוכב הערב - הבן של גבאי ״אבא יעשה שלטון סוציאל...
#
#                label
# 0          netanyahu
# 1          netanyahu
# 2          netanyahu
# 3          netanyahu
# 4          netanyahu
# ...              ...
# 2235  NitzanHorowitz
# 2236  NitzanHorowitz
# 2237  NitzanHorowitz
# 2238  NitzanHorowitz
# 2239  NitzanHorowitz
#
# [19299 rows x 3 columns]

# %%
all_data = hebrew_only

# %% [markdown]
# # Num of tweets per user id

# %%
all_data.groupby(['label'])['id'].count()
# Out:
# label
# AvigdorLiberman    1933
# NitzanHorowitz     2213
# ayelet__shaked     2237
# meravmichaelijs    1632
# naftalibennett     2046
# netanyahu          1883
# regev_miri         2999
# tamarzandberg      1827
# yairlapid          2529
# Name: id, dtype: int64

# %%
def plot_word_number_histogram(text):
    text.str.split().\
        map(lambda x: len(x)).\
        hist(range=(0,300))

plot_word_number_histogram(all_data["text"])

# %% [markdown]
# ## Graphs utils functions

# %%
def plot_top_non_stopwords_barchart(text, stop):
    new= text.str.split()
    new=new.values.tolist()
    corpus=[word for i in new for word in i]

    counter=Counter(corpus)
    most=counter.most_common()
    x, y=[], []
    for word,count in most[:50]:
        if (len(word)>1 and word not in stop):
            x.append(word)
            y.append(count)
            
    sns.barplot(x=y,y=invert_words(x))

# %%
def plot_top_ngrams_barchart(text, n=2):

    new= text.str.split()
    new=new.values.tolist()
    corpus=[word for i in new for word in i]

    def _get_top_ngram(corpus, n=None):
        vec = CountVectorizer(ngram_range=(n, n)).fit(corpus)
        bag_of_words = vec.transform(corpus)
        sum_words = bag_of_words.sum(axis=0) 
        words_freq = [(word, sum_words[0, idx]) 
                      for word, idx in vec.vocabulary_.items()]
        words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
        return words_freq[:20]

    top_n_bigrams=_get_top_ngram(text,n)[:20]
    x,y=map(list,zip(*top_n_bigrams))
    sns.barplot(x=y,y=invert_words(x))

# %%
def invert_words(words):
    return [w[::-1] for w in words]

def get_hebrew_stopwords():
    stop_path="./heb_stopwords.txt"
    with open(stop_path, encoding="utf-8") as in_file:
        lines=in_file.readlines()
        res=[l.strip() for l in lines]
        print(res[:4])
    return res

stop=get_hebrew_stopwords()
extra_words = ["QA", "the", "and", "to"]
stop += extra_words
# Out:
# ['את', 'לא', 'של', 'אני']

# %% [markdown]
# ## Clear data from symbols - emoji, flags, punctuations etc...

# %%
my_punctuation = string.punctuation.replace(",", "").replace(".","").replace("?","").replace("!","")
def remove_pe(text, p =string.punctuation):
    text_without = "".join([c for c in text if c not in p])
    text_without_pe =  emoji.get_emoji_regexp().sub(r'', text_without)
    return text_without_pe

def removeWeirdChars(text):
    weridPatterns = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u'\U00010000-\U0010ffff'
                               u"\u200d"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\u3030"
                               u"\ufe0f"
                               u"\u2069"
                               u"\u2066"
                               u"\u200c"
                               u"\u2068"
                               u"\u2067"
                               "]+", flags=re.UNICODE)
    return weridPatterns.sub(r'', text)

# %% [markdown]
# ## Clear hebrew data preview

# %%
all_data['text'] = all_data['text'].apply(lambda x: remove_pe(x, my_punctuation))\
                                 .apply(lambda x: re.sub(r'[A-Za-z]|http\S+|[0-9]+', '',x))\
                                 .apply(lambda x: removeWeirdChars(x))
print(all_data)
# Out:
#                        id                                               text  \
# 0     1400120105783152647                                        עוד פרטים
# 1     1400025751848632321  אני מברך את יצחק הרצוג על בחירתו לנשיא המדינה ...
# 2     1399768934337945601   הטענה המרכזית בתיק התפור   קרסה היום בבית המשפט
# 3     1399679823786696707  האיום הגדול ביותר עלינו זה האיום הקיומי שמוצב ...
# 4     1399670824064462854  למוסד יצא בצדק רב מוניטין של אחד מארגוני הביון...
# ...                   ...                                                ...
# 2235   886622894738079744  התנגדות המדינה לאימוץ ע״י הורים להטבים מראה שה...
# 2236   886279548807110657  עכשיו גם בתל אביב עדיין רחוק מאוד מהמספרים של ...
# 2237   885065513096839169  קצת הדתה להיום\r\nאיכה היתה לזונה קריה נאמנה, ...
# 2238   884683576662536192  ״ממשלת החלומות של החרדים״ הגדיר את זה   איך זה...
# 2239   884490381194297344  כוכב הערב  הבן של גבאי ״אבא יעשה שלטון סוציאלי...
#
#                label
# 0          netanyahu
# 1          netanyahu
# 2          netanyahu
# 3          netanyahu
# 4          netanyahu
# ...              ...
# 2235  NitzanHorowitz
# 2236  NitzanHorowitz
# 2237  NitzanHorowitz
# 2238  NitzanHorowitz
# 2239  NitzanHorowitz
#
# [19299 rows x 3 columns]

# %% [markdown]
# ## General data statistics

# %%
plot_top_non_stopwords_barchart(all_data["text"], stop)

# %% [markdown]
# # Yap utils - don't run for now

# %% [markdown]
# ## Read yap data - for now it's only on 80% from the data and not lovely - takes time to run so we will let it run on the weekend

# %%
# SET TEST AS FULL DATA, CHANGE IT!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# 15438  1279881181635522563  הוא ישב עם מומחה , כלכלן , בעל עסק ב כול ה ארץ...
#
#                 label
# 0           yairlapid
# 1      ayelet__shaked
# 2          regev_miri
# 3      NitzanHorowitz
# 4      naftalibennett
# ...               ...
# 15434  naftalibennett
# 15435       netanyahu
# 15436       yairlapid
# 15437      regev_miri
# 15438  naftalibennett
#
# [15439 rows x 3 columns]

# %%
# SET TEST AS FULL DATA, CHANGE IT!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
shuffled_data = all_data_yap_tmp_with_label.sample(frac=1).reset_index(drop=True)

# %%
plot_top_ngrams_barchart(all_data_yap_tmp_with_label[all_data_yap_tmp_with_label["label"]==user_ids[1]]["text"],2)

# %%
plot_top_non_stopwords_barchart(all_data_yap_tmp_with_label[all_data_yap_tmp_with_label["label"]==user_ids[1]]["text"], stop)

# %% [markdown]
# # Prepare data for ML algo

# %%
shuffled_data = all_data.sample(frac=1).reset_index(drop=True)

# %%
y = shuffled_data["label"]
x = shuffled_data

x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.2, random_state=42)

y_train = y_train.to_frame()
y_test = y_test.to_frame()

# %% [markdown]
# ## Train data statistics

# %% [markdown]
# ### netanyahu

# %%
plot_top_non_stopwords_barchart(x_train[x_train["label"]==user_ids[0]]["text"],stop)

# %%
plot_top_ngrams_barchart(x_train[x_train["label"]==user_ids[0]]["text"],2)

# %% [markdown]
# ### meravmichaelijs

# %%
plot_top_non_stopwords_barchart(x_train[x_train["label"]==user_ids[1]]["text"],stop)

# %%
plot_top_ngrams_barchart(x_train[x_train["label"]==user_ids[1]]["text"],2)

# %% [markdown]
# ### naftalibennett

# %%
plot_top_non_stopwords_barchart(x_train[x_train["label"]==user_ids[2]]["text"],stop)

# %%
plot_top_ngrams_barchart(x_train[x_train["label"]==user_ids[2]]["text"],2)

# %% [markdown]
# ### tamarzandberg

# %%
plot_top_non_stopwords_barchart(x_train[x_train["label"]==user_ids[3]]["text"],stop)

# %%
plot_top_ngrams_barchart(x_train[x_train["label"]==user_ids[3]]["text"],2)

# %% [markdown]
# ### yairlapid

# %%
plot_top_non_stopwords_barchart(x_train[x_train["label"]==user_ids[4]]["text"],stop)

# %%
plot_top_ngrams_barchart(x_train[x_train["label"]==user_ids[4]]["text"],2)

# %% [markdown]
# ### ayelet__shaked

# %%
plot_top_non_stopwords_barchart(x_train[x_train["label"]==user_ids[5]]["text"],stop)

# %%
plot_top_ngrams_barchart(x_train[x_train["label"]==user_ids[5]]["text"],2)

# %% [markdown]
# ### AvigdorLiberman

# %%
plot_top_non_stopwords_barchart(x_train[x_train["label"]==user_ids[6]]["text"],stop)

# %%
plot_top_ngrams_barchart(x_train[x_train["label"]==user_ids[6]]["text"],2)

# %% [markdown]
# ### regev_miri

# %%
plot_top_non_stopwords_barchart(x_train[x_train["label"]==user_ids[7]]["text"],stop)

# %%
plot_top_ngrams_barchart(x_train[x_train["label"]==user_ids[7]]["text"],2)

# %% [markdown]
# ### NitzanHorowitz

# %%
plot_top_non_stopwords_barchart(x_train[x_train["label"]==user_ids[8]]["text"],stop)

# %%
plot_top_ngrams_barchart(x_train[x_train["label"]==user_ids[8]]["text"],2)

# %%
# Modify y_test shape to fit evaluator
y_test.loc[:,"text"]=x_test["text"]
y_test = y_test.rename(columns={"label": "label"})

# %%
from evaluate import Evaluator
evaluator=Evaluator(y_test)
# Out:
# test_df has 3860 rows

# %% [markdown]
# # Yap - Data creation
# ## Used for analysis using YAP, but result weren't good. DONT RUN

# %%
sys.path.append("C:\HNLP\Ex3\YAP-Wrapper-master")
from yap_api import YapApi

class Processor:
    def __init__(self):
        #replace MY_TOKEN with the token you got from the langndata website
        self.yap_token="a073769bd24ead12455d64d220c0287b"
        self.ip='127.0.0.1:8000'
        self.yap=YapApi() 
        
    def get_yap_analysis(self, text):
        text= text.replace(r'"', r'\"')
        tokenized_text, segmented_text, lemmas, dep_tree, md_lattice, ma_lattice=self.yap.run(text, self.ip)                 
        dep_tree.set_index("num",inplace=True)
        print(type(lemmas))
        return lemmas

# %%
processor=Processor()

all_data_yap = pd.DataFrame(all_data)
for index, row in all_data_yap.iterrows():
    yap_result = processor.get_yap_analysis(row["text"])
    all_data_yap.loc[index, 'text'] = yap_result
    print("DONE " + str(index) + " OF " + str(all_data_yap.shape[0]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4e53d6801c67> in <module>
# ----> 1 processor=Processor()
#       2
#       3 x_test_yap = pd.DataFrame(x_test)
#       4 for index, row in x_test_yap.iterrows():
#       5     yap_result = processor.get_yap_analysis(row["text"])
#
# NameError: name 'Processor' is not defined

# %%
all_data_yap.to_csv("all_data_yap_shape.csv")

# %%
print(all_data_yap)
# Out:
#                         id                                               text
# 18708  1111991949114990599  שנה ה חמישים , שלח ה מוסד ב לונדון ב ה תמונה א...
# 15134  1096824496751865857  חיבור גנץ ניסנקורן ניחש מה זה נעשה ל תלוש ה חש...
# 14332   563412225189494785  אחרי יום ארוך , שימח ו מלא חוויה ב הוא פגש מאה...
# 8486   1284897196240973827  ב ה קיצור , ביב חירטט סתם שלף מ ה מותן בלי ה כ...
# 6612   1368278363115229188  תוכנית ריסטארט ל ה חינוך ב ישראל הקורונה חשף כ...
# ...                    ...                                                ...
# 11284  1296400835044429827  ב רוך ה הודה ל כול רבבה ה איש ה טוב ש נלחם למע...
# 11964  1253710145248530450  ב ה שבת ש בין יום ה שואה ל יום ה זיכרון ל חלל ...
# 5390   1259857453711310855  שר ו סגן שר ה ממשלה ה גדול ב תולדה ה מדינה הוק...
# 860     616258528542633984  הוא ה גאווה ש לן דווקא ב יום אלה ב הוא הוא התמ...
# 15795  1279881181635522563  הוא ישב עם מומחה , כלכלן , בעל עסק ב כול ה ארץ...
#
# [15439 rows x 2 columns]

# %%
x_train_yap = pd.read_csv("./yap_train.csv")

# %% [markdown]
# # ML ALGO - SGD Classifier

# %%
count_vectorizer=CountVectorizer(analyzer='word', ngram_range=(1, 2))
transformer=TfidfTransformer()
algo= SGDClassifier(loss='modified_huber', penalty='l2', alpha=1e-4, n_iter_no_change=20, random_state=42)
pipe = Pipeline([('vectorizer', count_vectorizer),
                    ('transformer', transformer),
                 ('algo', algo)])
pipe.fit(x_train["text"], y_train["label"])
predicted = pipe.predict(x_test["text"])
evaluator.evaluate(predicted)
# Out:
# Micro precision:0.667098445595855, recall:0.667098445595855, f1:0.667098445595855
# Macro precision:0.6753991279263255, recall:0.6708170587890244, f1:0.6692799545509103
# Accuracy: 0.667098445595855
# [[294   1  19   8  16  15  21  24   6]
#  [  0 267   1   4   9   4   1   9  14]
#  [ 20   6 310   9  16  14  11  21  10]
#  [  3   7  10 207  25  14   4  21  50]
#  [ 12   7  17  24 353  16  25  24  40]
#  [ 12  13  54  21  25 203  25  65  40]
#  [ 16   3  18  11  44  27 206  54  21]
#  [ 28   5  17  14  23  26  24 416  30]
#  [  5   3   7  28  33   8   1  26 319]]
# LABEL:  netanyahu F1:  0.7405541561712847  PREC:  0.7538461538461538  REC:  0.7277227722772277
# LABEL:  meravmichaelijs F1:  0.8599033816425121  PREC:  0.8557692307692307  REC:  0.8640776699029126
# LABEL:  naftalibennett F1:  0.7126436781609196  PREC:  0.6843267108167771  REC:  0.7434052757793765
# LABEL:  tamarzandberg F1:  0.6206896551724138  PREC:  0.6349693251533742  REC:  0.6070381231671554
# LABEL:  yairlapid F1:  0.664783427495292  PREC:  0.6488970588235294  REC:  0.6814671814671814
# LABEL:  ayelet__shaked F1:  0.5171974522292994  PREC:  0.6207951070336392  REC:  0.4432314410480349
# LABEL:  AvigdorLiberman F1:  0.5738161559888579  PREC:  0.6477987421383647  REC:  0.515
# LABEL:  regev_miri F1:  0.6693483507642799  PREC:  0.6303030303030303  REC:  0.7135506003430532
# LABEL:  NitzanHorowitz F1:  0.6645833333333334  PREC:  0.6018867924528302  REC:  0.7418604651162791

# %%
evaluator.show_errors(predicted, 100, user_ids[8])
# Out:
# overall, there are 111 instances with wrong kind
# כ אלף איש הצביעו מרצ בת״א עליה של  לעומת הבחירות באפריל והאמת שאני מרגיש את זה בכל מקום
# גאה בעיר שלי תל אביבים  תודה! true:  NitzanHorowitz predicted:  tamarzandberg
#
# עוד כותרות מגבאי בכנס  בי״ם ״נתניהו מנותק במה הוא מתעסק? בסיקור הצבא האוסטרלי בבאר שבע עלידי ערוץ  true:  NitzanHorowitz predicted:  regev_miri
#
# ממשלת ״אחדות״ כזו היא ממשלת ימין
# זו פחדנות, לא אחדות  true:  NitzanHorowitz predicted:  yairlapid
#
# הלב כואב על הירצחו של החייל דביר שורק יהי זכרו ברוך
# שולח תנחומים למשפחה אתכם באבלכם הכבד true:  NitzanHorowitz predicted:  yairlapid
#
# כן!  true:  NitzanHorowitz predicted:  meravmichaelijs
#
# במקום הליך משפטי ביבי רוצה תוכנית ריאליטי true:  NitzanHorowitz predicted:  yairlapid
#
# חילול? מי שלא רוצה  שלא ייסע למי שרוצה וצריך, חייבת להיות תחבורה ציבורית גם בסופשבוע הצביעות של המפלגות הדתיות לא תעצור אותנו החוק נותן את הסמכות לשר התחבורה, ובממשלה הבאה אנחנו נשתמש בה  true:  NitzanHorowitz predicted:  tamarzandberg
#
# התחלנו הצבעה מוקדמת  true:  NitzanHorowitz predicted:  ayelet__shaked
#
# תגיד את זה גם לחבריך שרוצים לעלות עם דחפור על בית המשפט  true:  NitzanHorowitz predicted:  ayelet__shaked
#
# כתבה מרגשת, באמת דמעות, של  על השיר ״אני חייל״ של שלמה ארצי, שכתב נמרוד גאון שנהרג במלחמת יום כיפור אחרי מותו, אמא שלו נתנה את השיר לשלמה שהלחין הכתבה שודרה עם פטירתה של האמא, אדית גאון, בגיל  אגב, היא היתה מניצולות רכבת קסטנר זכרה לברכה true:  NitzanHorowitz predicted:  regev_miri
#
# יפות הבלורית והתואר בזכותן ניצלו יהודי צפת  העיר בה מכהן הרב הבור אליהו  true:  NitzanHorowitz predicted:  ayelet__shaked
#
# ד״ש מברצלונה הסוערת  true:  NitzanHorowitz predicted:  regev_miri
#
# לא עורקים
# לא מזגזגים
# לא מתקרנפים
# נלחמים תמיד
# על החופש, השיוויון והשלום
# מרצ, ורק מרצ  true:  NitzanHorowitz predicted:  tamarzandberg
#
# ליברפול
#    מנצ׳סטר
#       הפועל ת״א
#
# אדום עולה עולה עולה!  true:  NitzanHorowitz predicted:  tamarzandberg
#
# ברכות לידידי סוויד, ראש מועצת פקיעין  הישוב המוביל בישראל באחוז הזכאים לבגרות קצת מאחוריו ברשימת המצטיינים בחינוך השכנים הדרוזים בחורפיש ובית ג׳ן הישג מרשים ביותר לאחד המקומות היפים והמעניינים בישראל true:  NitzanHorowitz predicted:  netanyahu
#
# מחאת בלפור חזקה מתמיד
# כ ל  ה כ ב ו ד !  true:  NitzanHorowitz predicted:  AvigdorLiberman
#
# יש נסיון מאורגן של הליכוד להעלים את פתקי ההצבעה של מרצ
#
# אם לא תהיה מרצ, נתניהו ובני הברית שלו יחסלו את ישראל החופשית
#
# צאו עכשיו להצביע מרצ  true:  NitzanHorowitz predicted:  tamarzandberg
#
# אם הפלסטיני ישים כיפה וישיר את התקווה יגידו שהוא עושה הצגות ומשקר אם ייצא בהצהרות עוינות יגידו שנחשף פרצופו האמיתי
# אם ישתף פעולה ויתאם בטחונית יגידו שהוא חלש ולא מייצג את עמו אם לא ישתף פעולה יאשימו אותו בסיוע לטרור
# אין פרטנר? נכון, אין פרטנר כי הממשלה לא רוצה שום הסדר true:  NitzanHorowitz predicted:  yairlapid
#
# על דרכה של מרצ ועל חשיבות השמאל מול מפלגות בועה ואווירה, בפודקאסט של הארץ   true:  NitzanHorowitz predicted:  tamarzandberg
#
# הדתה?
# כפייה דתית??
# אצבע בעין לחילונים???
# מה פתאום!
# הימין רק רוצה לחזק את סמכות בגץ מול דרג נבחר  true:  NitzanHorowitz predicted:  ayelet__shaked
#
# איך אומרים ברוסית מי שחי בבית זכוכית לא כדאי שיזרוק אבנים  true:  NitzanHorowitz predicted:  yairlapid
#
# ״מי שמע עליה לפני זהבי?״
# אף אחד אף אחד לא שמע על אחת הערים הגדולות בעולם, הבירה של החבל התעשייתי הגדול בעולם, ושהיתה השער ההיסטורי לסין מזל שיש את זהבי  true:  NitzanHorowitz predicted:  yairlapid
#
# חוזרים לדרך השלום  רק אתנו בממשלה זה אפשרי  true:  NitzanHorowitz predicted:  yairlapid
#
# טוב שהם לא מבקשים צבא נפרד משלהם  true:  NitzanHorowitz predicted:  yairlapid
#
# דמוקרטיה זה לחלשים בשביל מה באמת צריך כנסת אם יש בה רוב נגדנו? פשוט לא נכנס אותה וזהו, נפתרה הבעיה, וככה המשפט של ביבי לא יתחיל אף פעם ואם בסוף יהיה משפט, אז הרי ״לא צריך לקיים כל פסק דין״ אם יהיה נגדנו
# שר ״משפטים״ דיבור של עבריין  true:  NitzanHorowitz predicted:  tamarzandberg
#
# יש ירמי פינקוס חדש! מצפה לעונג שבת אמיתי  true:  NitzanHorowitz predicted:  regev_miri
#
# פוטין ישראל לא מכבדת את הריבונות הסורית אין ספק שמדובר באחד האנשים הציניים בעולם true:  NitzanHorowitz predicted:  netanyahu
#
# ידע ושיקר   true:  NitzanHorowitz predicted:  regev_miri
#
# שמו יאה לו בהחלט  true:  NitzanHorowitz predicted:  yairlapid
#
# לצערי אני נאלץ להחמיץ את ארוע הגאווה הראשון בכפר סבא בלי שום חומות!, אז באתי אמש לראות את ההכנות  true:  NitzanHorowitz predicted:  regev_miri
#
# חסר תקדים התנועות היהודיות הגדולות באמריקה יחרימו את שיחת הוועידה המסורתית עם הנשיא לקראת החגים, במחאה על דבריו המזעזעים בפרשת הנאצים true:  NitzanHorowitz predicted:  regev_miri
#
# ביקור אחרון באי השלום בנהריים
# זו התוצאה של החמצת היחסים עם ירדן ״והמצב המדיני הטוב בכל הזמנים״ שמוביל נתניהו  true:  NitzanHorowitz predicted:  yairlapid
#
# רוב הציבור הצביע שלוש פעמים בשנה האחרונה בעד ממשלת מרכזשמאל לולא ההתקפלות של חלקים במחנה, ובראשם גנץ ופרץ, היה ניתן להחליף את נתניהו אני מקווה שהלקח נלמד, והציבור ייתן את קולו בבחירות הקרובות לאלה שהוכיחו, כמו מרצ, כי הם לא משקרים ולא בוגדים בבוחרים true:  NitzanHorowitz predicted:  tamarzandberg
#
# צייץ האידיוט שאגב התחמק משירות צבאי במלחמת וייטנאם  true:  NitzanHorowitz predicted:  naftalibennett
#
# אתמול נתתי הרצאה על צ׳רצ׳יל היום אני מגיש משדר על טראמפ טוב שגם לנו בדורנו יש מנהיג דגול, דמות מופת, בראש העולם החופשי true:  NitzanHorowitz predicted:  regev_miri
#
# ספרו לי עוד על המתינות של דרעי והמפלגה החמה ומאירת הפנים שלו true:  NitzanHorowitz predicted:  tamarzandberg
#
# ביקור ניחומים בטמרה, בבית של אחמד חיג׳אזי שנקלע לקרב יריות בין כנופיית פשע למשטרה אחמד למד להיות אח מוסמך אהב לעזור, לטפל זה מה שניסה לעשות כששמע יריות לעזור כך נהרג מציאות של מערב פרוע הפשיעה הזו היא לא בעיה ״של הערבים״ זו מכת מדינה
#     true:  NitzanHorowitz predicted:  yairlapid
#
# תודה אחי  true:  NitzanHorowitz predicted:  yairlapid
#
# הלילה, בתכנית האחרונה של ״לילה טוב ישראל״ בערוץ , אספר על חקירת ה בשאלה מסמרת השיער, שכמוה לא נשאלה מעולם האם נשיא ארה״ב הוא סוכן רוסי
#  true:  NitzanHorowitz predicted:  regev_miri
#
# לא יודע אם לצחוק או לבכות  true:  NitzanHorowitz predicted:  yairlapid
#
# גבעתיים, ירוק בעיניים  true:  NitzanHorowitz predicted:  regev_miri
#
# הנה עוד חידוש ביזארימושחתעקום תבחרו בחוק ממשלת התפלצת של ביביגנץ יהיה אפשר למנות  שרים במשרד אחד כן כן לא רק  סגני שרים לכל שר, אלא גם שני שרים במשרד אחד שר חקלאות לבשרי ושר חקלאות לחלבי אחלה ממשלת חירום, ממש מופת שלטוני, ודוגמא נפלאה לאזרחים בשעה קשה זו true:  NitzanHorowitz predicted:  yairlapid
#
# אין כמוך אסתי   true:  NitzanHorowitz predicted:  regev_miri
#
# נחמה ריבלין היא מהאנשים הבודדים שהתדמית הציבורית שלהם דומה למי שהם באמת
# ומי שמכיר אותה אישית יודע שהיא אפילו יותר טובת לב ומאירת פנים וחכמה ממה שהעם מרגיש
# רפואה שלמה מכל הלב true:  NitzanHorowitz predicted:  yairlapid
#
# ביזיון בכנסת רוב ! לאופוזיציה להצעת  להקמת ועדת חקירה פרלמנטרית לפרשת הצוללות עכשיו היו״ר לוין עושה מעשה שלא יעשה ומבטל את ההצבעה ואחרי שהגיעו חכים מהקואליציה הוא מקיים הצבעה חוזרת בושה וחרפה לא היה דבר כזה בכנסת true:  NitzanHorowitz predicted:  tamarzandberg
#
# אני לא חשוד באהדה לשר, אבל עוד פחות אני אוהב חברות ביטוח שדוחות תביעות, ועוד מדליפות חומר אינטימי על המבוטחים שלהן  true:  NitzanHorowitz predicted:  meravmichaelijs
#
# אפרטהייד
# תכנית של רוע מזוקק  true:  NitzanHorowitz predicted:  tamarzandberg
#
# איזה מזל שיש לנו את כיפת ברזל, ואיזה מזל שיש לנו את עמיר פרץ שמח בשותפות אתו וגאה שהוא מוביל את הרשימה שלנו  true:  NitzanHorowitz predicted:  regev_miri
#
# אחד על אחד עם בסאם ג׳אבר, באולפן פאנט בטייבה, תכלס כמעט אולפן הבית שלי בחודשים האחרונים  true:  NitzanHorowitz predicted:  regev_miri
#
# נפגשתי עם גורמים אמריקאים בכירים והבהרתי להם שהסיפוח הוא אסון לישראל ואסון לאזור במקביל למאבק הפוליטי שלנו והמערכה על דעת הקהל בישראל, אני מתכוון להמשיך להיפגש עם דיפלומטים ונציגים בינלאומיים כדי לעצור את הסיפוח ולמנוע מהממשלה לקבור את הסיכוי לשלום true:  NitzanHorowitz predicted:  netanyahu
#
# אף בנאדם רציני לא צריך להגיד ״אמרנו לכם״  לא משמאל ולא מימין זה נבוב ומיותר מה שצריך זה לנסות לשנות את המצב, ולא רק ״לנהל את הסכסוך״ true:  NitzanHorowitz predicted:  yairlapid
#
# ״לא באנו לעסוק בבעיות המשפטיות של נתניהו״  חברים, מעולם לא היה שם שום דבר אחר לא בקורונה, ולא לפני הקורונה כבר שנתיים שכל הטירוף הפוליטי במדינה נובע מהשחיתות של נתניהו ומי שחשב שהמשבר הבריאותי והכלכלי העצום ישנה משהו  פשוט לא מבין עם מי יש לו עסק  true:  NitzanHorowitz predicted:  yairlapid
#
# גם מכפר המכביה אני עוקב בהתרגשות אחר ההתחלה היום של רישום זוגות מהקהילה הגאה ובכלל זוגות בעיריית תל אביב  לראשונה בישראל יוזמה של חברי הטוב איתי פנקס, ממרצ כמובן והנה הוא עם בן זוגו יואב ארד וראש העיר רון חולדאי
# חברים, זו מהפיכה
# כל הכבוד וחודש גאווה שמח!  true:  NitzanHorowitz predicted:  regev_miri
#
# אנרגיות חזקות בהתנעת מטה הבחירות המשותף בירושלים כל יום אנחנו בעיר אחרת והשטח שלנו מאושר מהחיבור
# העבודהגשרמרצ!  true:  NitzanHorowitz predicted:  naftalibennett
#
# פה נמצא הכסף הגדול בקומבינות ממוסדות, בעיוותים ״חוקיים״ זו השיטה ולנו מוכרים שלמשרד הבריאות אין  מיליון שקל למניעת התאבדויות, ולמשרד הרווחה אין  מיליון להוסטל לאוטיסטים
# אז אנחנו נמשיך לשלם עשרות אחוזים מס על הכנסות מעבודה, והקרנות האלה יקבלו פטור! על גלגול הון צדק  true:  NitzanHorowitz predicted:  yairlapid
#
# קללת הפיצול הרעה החולה של הפוליטיקה הישראלית true:  NitzanHorowitz predicted:  yairlapid
#
# אופיר פינס, לשעבר מזכ״ל מפלגת העבודה ושר הפנים, צודק  true:  NitzanHorowitz predicted:  regev_miri
#
# אין ימין, אין שמאל יש רק ביבי
#
# מעריץ את ביבי  יהודי טוב
# מתנגד לביבי  אנטישמי
#
# מה היינו עושים בלעדיו  איך היינו מבחינים בין טוב ורע בעולמנו? true:  NitzanHorowitz predicted:  yairlapid
#
# הכי חשוב כעת לתת מענה לתושבים ולחתור להפסקת אש
# עיתוי הפעולה בעייתי מאוד ברגע ההכרעה על הקמת ממשלה, כשנתניהו נלחם על הישרדותו הפוליטית, כל החלטה שלו, כשאין בידיו מנדט, חשודה באופן בלתי נמנע בניגוד אינטרסים ישראל זקוקה לראש ממשלה במשרה מלאה שלא נתון ללחצים משפטיים ופוליטיים true:  NitzanHorowitz predicted:  yairlapid
#
# זו התעללות בציבור לא יתכן שבמשבר כזה שרים ופקידים סותרים אחד את השני, מוסרים הודעות הפוכות, ומטריפים את העם משפחות של ילדים עם צרכים מיוחדים הן במצב קשה אי אפשר לשחק בהם ככה יש גם מורות, עובדים, מטפלים לאנשים יש חיים צריך גורם אחד, אחד, שיודיע באופן מוסמך ולהפסיק את הבלגן  true:  NitzanHorowitz predicted:  yairlapid
#
# האם יש בישראל שר לביטחון פנים? אם כן, אז כנראה שאין בו צורך אם  מאז אמש הוא מסתתר true:  NitzanHorowitz predicted:  tamarzandberg
#
# אפס במנהיגות true:  NitzanHorowitz predicted:  regev_miri
#
# שוברים שתיקה ומחסום ווטש לא פועלים נגד חיילי צה״ל, אלא בעדם בעד שיפסיקו לעשות משימות שיטור על אוכלוסייה אזרחית, בעד שיפסיקו לעצור ילדים, בעד סיום הכיבוש
# תלמידים שמבקרים בחברון חייבים לשמוע את האמת על מה שמתרחש שם ורפי פרץ? שוב הוא מראה שאין לו מושג מה זה דמוקרטיה  true:  NitzanHorowitz predicted:  tamarzandberg
#
# לא, זה לא סמל בודהיסטי עתיק בהפגנות האלימות בארה״ב  true:  NitzanHorowitz predicted:  yairlapid
#
# מאפיה  true:  NitzanHorowitz predicted:  regev_miri
#
# עכשיו בכנסת שומרים על ספירת המעטפות הכפולות  true:  NitzanHorowitz predicted:  tamarzandberg
#
# הימין משתולל איך אנחנו מעיזים להטיל ספק במניעי הפעולה, והנה ביבי בעצמו מבקש למסור ״הודעה מיוחדת״ בכנסת כולם נוהרים למליאה והוא עולה לדוכן ועושה סיבוב מתריס, שכולו פוליטיקה קטנה ועלובה, שמבוסס כמה מפתיע על הסתה נגד השמאל והערבים ואז יורד עם חיוך מרוח על פניו זהו,ההצגה הצליחה true:  NitzanHorowitz predicted:  tamarzandberg
#
# צריך ואפשר להקים ״ממשלת משימה״ כל הפרטים  הערב אצל אופירה וברקו  true:  NitzanHorowitz predicted:  naftalibennett
#
# חשוב פורסם עכשיו   זה המועד לדיון בעתירת מרצ ואחרים נגד חוק הלאום למרות התנגדות שרי המשפטים שקד ואוחנה שטענו כי לבגצ אין סמכות לדון נגד חוק יסוד, הדיון יתקיים בהרכב מורחב  או  הכולל כמעט את כל השופטים המכהנים, וגם נקבע מועד קרוב יחסית, למרות בקשות הדחיה של המדינה true:  NitzanHorowitz predicted:  tamarzandberg
#
# מו״מ עם נתניהו? על מה בדיוק? על שוחד, מירמה והפרת אמונים? נתניהו לא ראוי להיות ראש ממשלה נקודה
# האיש הזה הגיש דף ריק ! כעיקרי הטיעונים שלו לשימוע וגנץ נותן לו חבל הצלה? הרי הסיבה העיקרית להצבעה לכחוללבן היתה להחליף את ביבי אל תתנו לו לנצח עכשיו יש אופציה לממשלה אחרת true:  NitzanHorowitz predicted:  yairlapid
#
# סוף סוף אישה בראש אחת משלוש הגדולות true:  NitzanHorowitz predicted:  ayelet__shaked
#
# מערכת הבחירות מתנהלת כבר שבועיים, הכל סוער ורוגש, אבל על מה? בינתיים היחידה  שמדברת אידיאולוגיה ומציגה חזון מדיני ברור זו
# אפשר להסכים או לא אבל לפחות היא שמה את הדבר הכי חשוב על השולחן true:  NitzanHorowitz predicted:  tamarzandberg
#
# יום שישי השחור, חורף, גשם  במקום להתרוצץ בחוץ ולזרוק כסף על דברים שלא צריך, אפשר להאזין בנחת לפרק החדש בפודקאסט שלי על הנושא הכי חם עכשיו תחבורה עירונית  בגובה העיניים  true:  NitzanHorowitz predicted:  naftalibennett
#
# לכל לוכדי העריקים, מפיצי השמועות ומלבי הסכסוכים  הגעתם לכתובת הלא נכונה חפשו את מזלכם ברשימה אחרת
# ומה כן? בדיוק כמו שאמרנו בקמפיין  אנחנו רוצים להחליף את נתניהו בממשלה בראשות גנץ ואנחנו בתוכה איננו פוסלים שום קבוצה ושום מיגזר
# נביא שינוי ותקווה לישראל
# שבת שלום לכולם true:  NitzanHorowitz predicted:  yairlapid
#
# הגיע הרגע המכריע
# עכשיו מרצ חייבת אתכם
#
# צאו, תצביעו מרצ, דברו עם חברים וחברות  הקולות שלכם יכריעו את כל הבחירות האלה  true:  NitzanHorowitz predicted:  tamarzandberg
#
# צודקת  true:  NitzanHorowitz predicted:  ayelet__shaked
#
# ״הקול להצלת הדמוקרטיה״  יהושע סובול מסביר למה מרצ המון תודה חבר  true:  NitzanHorowitz predicted:  tamarzandberg
#
# קבלו סרטון של קמפיין השיוויון שלנו
# מתנצל מראש שאין פקקים ובקבוקים  true:  NitzanHorowitz predicted:  regev_miri
#
# איזו תמונה! ראיתי אותה היום ובדקתי השנה   בן גוריון  מ׳ מעניק דרגות קצונה בבה״ד  לחניך המצטיין משה לוי  מ׳, ״משה וחצי״, לימים הרמטכ״ל
# היום יום השנה לפטירתו, ז״ל  true:  NitzanHorowitz predicted:  tamarzandberg
#
# מה מעמד נתניהו היום? ב מול בוז׳י הקים ממשלה בסוף ׳ פיזור הכנסת והפך ר״מ מעבר באפריל ׳ בחירות קיבל את המנדט, כשל בהקמת ממשלה ביוני שוב פיזור כנסת, הוא ממשיך כר״מ של מעבר כפול בספט׳ בחירות, שוב מקבל מנדט ועדיין לא מצליח זה לא ״ר״מ יוצאמעבר״ זה שלטון על כרעי תרנגולת true:  NitzanHorowitz predicted:  yairlapid
#
# הליכודשים  לא עובד אנשים מצביעים ליכוד בגלל מה שהוא אם יחשדו שמתחפש  לא יצביעו לו עדיף להשקיע את המאמץ בחיזוק השמאל ולא להיכנע מראש true:  NitzanHorowitz predicted:  yairlapid
#
# הפרדה מיגדריתגזעית בחוק כופה היא פסולה, בוודאי בחינוך בפסק הדין המכונן ״בראון״ על הפרדת שחוריםלבנים בבי״ס, פסל העליון האמריקאי את ״נפרד אבל שווה״ אם זה נפרד זה לא שווה ולא יכול להיות שווה  לא בעיקרון ולא ביישום true:  NitzanHorowitz predicted:  tamarzandberg
#
# נו חבר, דער קאָראָנאַ ווירוס איז א גוי, פארשטייט נישט יידיש  true:  NitzanHorowitz predicted:  meravmichaelijs
#
# צעירה ״תומכת חרם״ באה לישראל, ללמוד באוניברסיטה העברית בירושלים
# סלקטורים יקרים מהשב״כ, לא נראה לכם שיש פה סתירה? מי שתומך בחרם על ישראל לא בא ללמוד ולגור בה true:  NitzanHorowitz predicted:  yairlapid
#
# לידיעת הח״כים החרדים והם יודעים העבודות הגדולות מחר ברכבת מתבצעות כל כמה חודשים, ואגב בכל שבת יש עבודות תחזוקה גם בהרבה מערכות אחרות הממשלה הזו, כמו כל אחת לפניה ואחריה, ״מחללת״ שבת לא רוצים להיות אחראים? שבו באופוזיציה הצחקתי אתכם? ברור true:  NitzanHorowitz predicted:  yairlapid
#
# אז מה היה לנו השבוע?  true:  NitzanHorowitz predicted:  regev_miri
#
# אמחייה!  true:  NitzanHorowitz predicted:  regev_miri
#
# הימין החדש דומה לבידיאס שניהם אומרים שישראל והציונות, מעצם הווייתן, הן גזעניות ומפלות ערבים הבידיאס אומר את זה בסלידה, הימין בגאווה עבורם ״מדינה יהודית״ משמעותה ״רק ליהודים״ ולא יכולה להיות ״יהודית ודמוקרטית״
# לצערי, אחרי חוק הלאום זה הולך לשם עיוות של הציונות true:  NitzanHorowitz predicted:  tamarzandberg
#
# נתניהו שגה כשחתם על הצהרה מפורטת כל כך עם פולין בעניין אירועים שהתרחשו בשואה הוא לא היסטוריון, וכל זה לא בתחום מומחיותו וגם לא מתפקידו יש שם מסקנות שנמצאות בוויכוח אפילו בפולין ההודעה החריגה של יד ושם  המוסד הישראלי המוסמך  לא מאפשרת התחמקות הממשלה תהיה חייבת לבטל את ההסכם true:  NitzanHorowitz predicted:  yairlapid
#
# ״תחזור לאפריקה״, צעק יו״ר הבית היהודי בחיפה על נציג מרצ במועצה, הרב דובי חיון, במהלך דיון גדוש הומופוביה על תעודת משפחה לזוגות להט״בים יוזמה של  היועץ הפרלמנטרי שלי! ו אגב, ראשת העיר קליש שהתנגדה ברחה מהדיון ההחלטה אושרה, החשוכים הפסידו, וחיפה ניצחה true:  NitzanHorowitz predicted:  ayelet__shaked
#
# מבחינה תחבורתית יש בירושלים תכנון טוב מתל אביב התחנה המרכזית צמודה ממש לרכבת הקלה ולרכבת החדשה, וכך יש אוטובוסרכבת קלהרכבת מהירה ״גב אל גב״ בתל אביב שופכים מיליארדים והתחנות לא יהיו צמודות  לא בארלוזורוב ולא בעזריאלי זה מחדל ואיוולת עם השלכות קשות true:  NitzanHorowitz predicted:  tamarzandberg
#
# הרבה מתפלאים שיש גל נגדי של מחאה נגד המחאה  ״איך אפשר בכלל להתנגד למחאה נגד אלימות כלפי נשים?״
# איך? עובדה
# הרי אם כולם היו מסכימים לא היה צורך בשום מחאה מלכתחילה true:  NitzanHorowitz predicted:  tamarzandberg
#
# ברכות לגילה אדרעי הפייטרית שחוזרת בגדול לראשות ועד עובדי הרכבת מנהיגת עובדים אמיתית, קטר חזק true:  NitzanHorowitz predicted:  regev_miri
#
# לא מבזבזים אפילו רגע מרצ בכנסת או  לנתניהו  זה בידיים שלכם
#
# אל תחכו לאחר כך שתו קפה, צאו להצביע מרצ, ותתפנו להמשך היום, כמעט
#
# קודם שכנעו עוד שלושה חברים שחייבים להצביע מרצ זה בשביל הערכים שלכם, ובשביל למנוע ממשלה בן גביר וסמוטריץ׳
#
# אסור לאבד את מרצ  true:  NitzanHorowitz predicted:  tamarzandberg
#
# הוא מדבר על לשמור על הטלפון?
# כרטיס אשראי הוא לא יודע לשמור איזו משפחה  true:  NitzanHorowitz predicted:  yairlapid
#
# כבר מזמן אני חושב שהסיבה האמיתית למקום הגבוה של ישראל במדד האושר העולמי זה מזג האוויר גם אם אתה שפוף, אתה יוצא לשמש ולשמיים הכחולים, ומייד משתפר המצב רוח יום חלום  true:  NitzanHorowitz predicted:  yairlapid
#
# האיש החשוב בעולם קם גם הבוקר מעורער ומוטרף  הפעם בגלל הספר החדש בו נאמר שכל הסובבים אותו, ללא יוצא מן הכלל, חושבים שהוא לא יציב ומיהר לצייץ כך ״אני לא רק חכם, אני גאון, וגאון יציב!״ כן true:  NitzanHorowitz predicted:  regev_miri
#
# חג שמח חברים !  true:  NitzanHorowitz predicted:  tamarzandberg
#
# לא רע  true:  NitzanHorowitz predicted:  yairlapid
#
# יצא עכשיו ומוצדק לצערי
# מרצ בסכנה ממשית  true:  NitzanHorowitz predicted:  tamarzandberg

# %% [markdown]
# # ML ALGO - Logistic Regression

# %%
count_vectorizer=CountVectorizer(analyzer='word', ngram_range=(1, 2))
transformer=TfidfTransformer()
algo = LogisticRegression(max_iter=100)
pipe = Pipeline([('vectorizer', count_vectorizer),
                    ('transformer', transformer),
                 ('algo', algo)])
pipe.fit(x_train["text"], y_train["label"])
predicted = pipe.predict(x_test["text"])
evaluator.evaluate(predicted)
# Out:
# D:\Users\yelfs\AppData\Local\Programs\Python\Python36\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# Micro precision:0.611139896373057, recall:0.611139896373057, f1:0.611139896373057
# Macro precision:0.6482022018730974, recall:0.6062015316479881, f1:0.6136851639675659
# Accuracy: 0.611139896373057
# [[249   2  20   8  28  18  25  47   7]
#  [  0 246   0   5   9   3   1  17  28]
#  [ 20   5 275   3  27  16  11  35  25]
#  [  2   8   8 149  39  15   3  38  79]
#  [ 11   4  13  20 340  15  16  51  48]
#  [  8   9  42  14  36 176  19 102  52]
#  [  9   3  15   6  56  25 177  86  23]
#  [ 17   4  10   5  31  16  20 448  32]
#  [  4   2   8  17  46   9   0  45 299]]
# LABEL:  netanyahu F1:  0.6878453038674032  PREC:  0.778125  REC:  0.6163366336633663
# LABEL:  meravmichaelijs F1:  0.831081081081081  PREC:  0.8692579505300353  REC:  0.7961165048543689
# LABEL:  naftalibennett F1:  0.6806930693069306  PREC:  0.7033248081841432  REC:  0.6594724220623501
# LABEL:  tamarzandberg F1:  0.5246478873239436  PREC:  0.6563876651982379  REC:  0.436950146627566
# LABEL:  yairlapid F1:  0.6017699115044247  PREC:  0.5555555555555556  REC:  0.6563706563706564
# LABEL:  ayelet__shaked F1:  0.4687083888149135  PREC:  0.6006825938566553  REC:  0.38427947598253276
# LABEL:  AvigdorLiberman F1:  0.5267857142857143  PREC:  0.6507352941176471  REC:  0.4425
# LABEL:  regev_miri F1:  0.6170798898071624  PREC:  0.5155350978135789  REC:  0.7684391080617495
# LABEL:  NitzanHorowitz F1:  0.5845552297165201  PREC:  0.5042158516020236  REC:  0.6953488372093023

# %%
evaluator.show_errors(predicted, 100, user_ids[8])
# Out:
# overall, there are 131 instances with wrong kind
# כ אלף איש הצביעו מרצ בת״א עליה של  לעומת הבחירות באפריל והאמת שאני מרגיש את זה בכל מקום
# גאה בעיר שלי תל אביבים  תודה! true:  NitzanHorowitz predicted:  tamarzandberg
#
# עוד כותרות מגבאי בכנס  בי״ם ״נתניהו מנותק במה הוא מתעסק? בסיקור הצבא האוסטרלי בבאר שבע עלידי ערוץ  true:  NitzanHorowitz predicted:  regev_miri
#
# ממשלת ״אחדות״ כזו היא ממשלת ימין
# זו פחדנות, לא אחדות  true:  NitzanHorowitz predicted:  yairlapid
#
# הלב כואב על הירצחו של החייל דביר שורק יהי זכרו ברוך
# שולח תנחומים למשפחה אתכם באבלכם הכבד true:  NitzanHorowitz predicted:  regev_miri
#
# כן!  true:  NitzanHorowitz predicted:  meravmichaelijs
#
# במקום הליך משפטי ביבי רוצה תוכנית ריאליטי true:  NitzanHorowitz predicted:  yairlapid
#
#  שרים?!
# טירוף מושחת true:  NitzanHorowitz predicted:  yairlapid
#
# חילול? מי שלא רוצה  שלא ייסע למי שרוצה וצריך, חייבת להיות תחבורה ציבורית גם בסופשבוע הצביעות של המפלגות הדתיות לא תעצור אותנו החוק נותן את הסמכות לשר התחבורה, ובממשלה הבאה אנחנו נשתמש בה  true:  NitzanHorowitz predicted:  yairlapid
#
# התחלנו הצבעה מוקדמת  true:  NitzanHorowitz predicted:  ayelet__shaked
#
# תגיד את זה גם לחבריך שרוצים לעלות עם דחפור על בית המשפט  true:  NitzanHorowitz predicted:  ayelet__shaked
#
# כתבה מרגשת, באמת דמעות, של  על השיר ״אני חייל״ של שלמה ארצי, שכתב נמרוד גאון שנהרג במלחמת יום כיפור אחרי מותו, אמא שלו נתנה את השיר לשלמה שהלחין הכתבה שודרה עם פטירתה של האמא, אדית גאון, בגיל  אגב, היא היתה מניצולות רכבת קסטנר זכרה לברכה true:  NitzanHorowitz predicted:  regev_miri
#
# יפות הבלורית והתואר בזכותן ניצלו יהודי צפת  העיר בה מכהן הרב הבור אליהו  true:  NitzanHorowitz predicted:  regev_miri
#
# ד״ש מברצלונה הסוערת  true:  NitzanHorowitz predicted:  regev_miri
#
# לא עורקים
# לא מזגזגים
# לא מתקרנפים
# נלחמים תמיד
# על החופש, השיוויון והשלום
# מרצ, ורק מרצ  true:  NitzanHorowitz predicted:  tamarzandberg
#
# ליברפול
#    מנצ׳סטר
#       הפועל ת״א
#
# אדום עולה עולה עולה!  true:  NitzanHorowitz predicted:  tamarzandberg
#
# ברכות לידידי סוויד, ראש מועצת פקיעין  הישוב המוביל בישראל באחוז הזכאים לבגרות קצת מאחוריו ברשימת המצטיינים בחינוך השכנים הדרוזים בחורפיש ובית ג׳ן הישג מרשים ביותר לאחד המקומות היפים והמעניינים בישראל true:  NitzanHorowitz predicted:  regev_miri
#
# מחאת בלפור חזקה מתמיד
# כ ל  ה כ ב ו ד !  true:  NitzanHorowitz predicted:  regev_miri
#
# אם הפלסטיני ישים כיפה וישיר את התקווה יגידו שהוא עושה הצגות ומשקר אם ייצא בהצהרות עוינות יגידו שנחשף פרצופו האמיתי
# אם ישתף פעולה ויתאם בטחונית יגידו שהוא חלש ולא מייצג את עמו אם לא ישתף פעולה יאשימו אותו בסיוע לטרור
# אין פרטנר? נכון, אין פרטנר כי הממשלה לא רוצה שום הסדר true:  NitzanHorowitz predicted:  yairlapid
#
# דברים חריפים ביותר של בני בגין על איילת שקד והתקפתה נגד בית המשפט העליון ״דברי ההבל האלה, הדיבורים הגסים האלה, נוגעים ממש בחישוקים השמרים עלינו זהירות רבותי  כאן נפערת תהום!״ בנט מביט בו בתדהמה  עכשיו בכנס במרכז בגין לרגל ספרו של , בנוכחות הנשיא ריבלין true:  NitzanHorowitz predicted:  ayelet__shaked
#
# על דרכה של מרצ ועל חשיבות השמאל מול מפלגות בועה ואווירה, בפודקאסט של הארץ   true:  NitzanHorowitz predicted:  tamarzandberg
#
# הדתה?
# כפייה דתית??
# אצבע בעין לחילונים???
# מה פתאום!
# הימין רק רוצה לחזק את סמכות בגץ מול דרג נבחר  true:  NitzanHorowitz predicted:  ayelet__shaked
#
# איך אומרים ברוסית מי שחי בבית זכוכית לא כדאי שיזרוק אבנים  true:  NitzanHorowitz predicted:  yairlapid
#
# פניתי ליועץ המשפטי לממשלה כדי שיורה על חקירה פלילית נגד שר האוצר ורה״מ בעקבות העדויות של המנכ״לית וראש אגף תקציבים לשעבר בתכנית ״עובדה״ לטענתם, השר כפה עליהם לזייף נתונים כדי לייצר מצג שווא  מה שמקים חשד פלילי להפרת אמונים קשה לא ניתן להתעלם מטענות כאלה ויש לקיים חקירה יסודית true:  NitzanHorowitz predicted:  tamarzandberg
#
# ״מי שמע עליה לפני זהבי?״
# אף אחד אף אחד לא שמע על אחת הערים הגדולות בעולם, הבירה של החבל התעשייתי הגדול בעולם, ושהיתה השער ההיסטורי לסין מזל שיש את זהבי  true:  NitzanHorowitz predicted:  yairlapid
#
# חוזרים לדרך השלום  רק אתנו בממשלה זה אפשרי  true:  NitzanHorowitz predicted:  yairlapid
#
# טוב שהם לא מבקשים צבא נפרד משלהם  true:  NitzanHorowitz predicted:  yairlapid
#
# איזו תנועה מעולה דרור ישראל בבוקר ראיתי אותם באוהל זכור על רצח רבין, ובלילה בהפגנה מול קפה נואר על זכויות העובדים כל הכבוד להם, עושים המון  true:  NitzanHorowitz predicted:  naftalibennett
#
# משפחת נתניהו זועמת על פייק ניוז
# הימין מתלונן על אלימות
# המתנחלים מוחים על בניה לא חוקית של הפלסטינים
# התקשורת הביביסטית קובלת על סתימת פיות
# ההומופובים הממירים זועקים על פגיעה בחופש העיסוק
# שלוחי נתניהו בוכים שהוא נכה כלכלי
# ונגמר לי הטישיו
# התקרבנותם אמנותם ציווחת הקוזק הנגזל true:  NitzanHorowitz predicted:  yairlapid
#
# דמוקרטיה זה לחלשים בשביל מה באמת צריך כנסת אם יש בה רוב נגדנו? פשוט לא נכנס אותה וזהו, נפתרה הבעיה, וככה המשפט של ביבי לא יתחיל אף פעם ואם בסוף יהיה משפט, אז הרי ״לא צריך לקיים כל פסק דין״ אם יהיה נגדנו
# שר ״משפטים״ דיבור של עבריין  true:  NitzanHorowitz predicted:  yairlapid
#
# יש ירמי פינקוס חדש! מצפה לעונג שבת אמיתי  true:  NitzanHorowitz predicted:  regev_miri
#
# פוטין ישראל לא מכבדת את הריבונות הסורית אין ספק שמדובר באחד האנשים הציניים בעולם true:  NitzanHorowitz predicted:  yairlapid
#
# חשוד לא חייב מייד להתפטר אם וכאשר יהפוך לנאשם  כן ואם החקירות מקשות על תפקודו או שהוא מקשה עליהן עליו לצאת לנבצרות וימונה לו ממלא מקום true:  NitzanHorowitz predicted:  yairlapid
#
# ידע ושיקר   true:  NitzanHorowitz predicted:  regev_miri
#
# שמו יאה לו בהחלט  true:  NitzanHorowitz predicted:  yairlapid
#
# לצערי אני נאלץ להחמיץ את ארוע הגאווה הראשון בכפר סבא בלי שום חומות!, אז באתי אמש לראות את ההכנות  true:  NitzanHorowitz predicted:  regev_miri
#
# חסר תקדים התנועות היהודיות הגדולות באמריקה יחרימו את שיחת הוועידה המסורתית עם הנשיא לקראת החגים, במחאה על דבריו המזעזעים בפרשת הנאצים true:  NitzanHorowitz predicted:  regev_miri
#
# ביקור אחרון באי השלום בנהריים
# זו התוצאה של החמצת היחסים עם ירדן ״והמצב המדיני הטוב בכל הזמנים״ שמוביל נתניהו  true:  NitzanHorowitz predicted:  yairlapid
#
# רוב הציבור הצביע שלוש פעמים בשנה האחרונה בעד ממשלת מרכזשמאל לולא ההתקפלות של חלקים במחנה, ובראשם גנץ ופרץ, היה ניתן להחליף את נתניהו אני מקווה שהלקח נלמד, והציבור ייתן את קולו בבחירות הקרובות לאלה שהוכיחו, כמו מרצ, כי הם לא משקרים ולא בוגדים בבוחרים true:  NitzanHorowitz predicted:  tamarzandberg
#
# צייץ האידיוט שאגב התחמק משירות צבאי במלחמת וייטנאם  true:  NitzanHorowitz predicted:  regev_miri
#
# אתמול נתתי הרצאה על צ׳רצ׳יל היום אני מגיש משדר על טראמפ טוב שגם לנו בדורנו יש מנהיג דגול, דמות מופת, בראש העולם החופשי true:  NitzanHorowitz predicted:  regev_miri
#
# ספרו לי עוד על המתינות של דרעי והמפלגה החמה ומאירת הפנים שלו true:  NitzanHorowitz predicted:  regev_miri
#
# תודה אחי  true:  NitzanHorowitz predicted:  netanyahu
#
# מסקנות סוריה
#  כאוס באזור רע לישראל, מאפשר חדירת גורמים מסוכנים
#  רוסיה לא חברה שלנו, פוטין לא סופר את נתניהו, ולנו אין מה לחפש אצלם
#  טראמפ לא מספק את הסחורה מבחינת ישראל  לא בסוריה ולא בכלל true:  NitzanHorowitz predicted:  yairlapid
#
# חשיפה העובדות הסוציאליות עונדות סרט אדום!
# מי מימן את הסרטים האלה?
# ולמה דווקא אדום?
# אתם בטח כבר יודעים את התשובה  true:  NitzanHorowitz predicted:  yairlapid
#
# הלילה, בתכנית האחרונה של ״לילה טוב ישראל״ בערוץ , אספר על חקירת ה בשאלה מסמרת השיער, שכמוה לא נשאלה מעולם האם נשיא ארה״ב הוא סוכן רוסי
#  true:  NitzanHorowitz predicted:  regev_miri
#
# לא יודע אם לצחוק או לבכות  true:  NitzanHorowitz predicted:  yairlapid
#
# גבעתיים, ירוק בעיניים  true:  NitzanHorowitz predicted:  regev_miri
#
# הורוביץ בממשלה איתנו, רבנים לא יקבלו פרס על הפצת הומופוביה ושנאה  true:  NitzanHorowitz predicted:  yairlapid
#
# הנה עוד חידוש ביזארימושחתעקום תבחרו בחוק ממשלת התפלצת של ביביגנץ יהיה אפשר למנות  שרים במשרד אחד כן כן לא רק  סגני שרים לכל שר, אלא גם שני שרים במשרד אחד שר חקלאות לבשרי ושר חקלאות לחלבי אחלה ממשלת חירום, ממש מופת שלטוני, ודוגמא נפלאה לאזרחים בשעה קשה זו true:  NitzanHorowitz predicted:  yairlapid
#
# נחמה ריבלין היא מהאנשים הבודדים שהתדמית הציבורית שלהם דומה למי שהם באמת
# ומי שמכיר אותה אישית יודע שהיא אפילו יותר טובת לב ומאירת פנים וחכמה ממה שהעם מרגיש
# רפואה שלמה מכל הלב true:  NitzanHorowitz predicted:  yairlapid
#
# ביזיון בכנסת רוב ! לאופוזיציה להצעת  להקמת ועדת חקירה פרלמנטרית לפרשת הצוללות עכשיו היו״ר לוין עושה מעשה שלא יעשה ומבטל את ההצבעה ואחרי שהגיעו חכים מהקואליציה הוא מקיים הצבעה חוזרת בושה וחרפה לא היה דבר כזה בכנסת true:  NitzanHorowitz predicted:  tamarzandberg
#
# אני לא חשוד באהדה לשר, אבל עוד פחות אני אוהב חברות ביטוח שדוחות תביעות, ועוד מדליפות חומר אינטימי על המבוטחים שלהן  true:  NitzanHorowitz predicted:  meravmichaelijs
#
# מתחילים את הערב הגדול הזה בגשר עין המפרץ, בפאתי עכו
# בואו להפגין!  true:  NitzanHorowitz predicted:  regev_miri
#
# אפרטהייד
# תכנית של רוע מזוקק  true:  NitzanHorowitz predicted:  naftalibennett
#
# איזה מזל שיש לנו את כיפת ברזל, ואיזה מזל שיש לנו את עמיר פרץ שמח בשותפות אתו וגאה שהוא מוביל את הרשימה שלנו  true:  NitzanHorowitz predicted:  regev_miri
#
# אחד על אחד עם בסאם ג׳אבר, באולפן פאנט בטייבה, תכלס כמעט אולפן הבית שלי בחודשים האחרונים  true:  NitzanHorowitz predicted:  regev_miri
#
# סמוטריץ, אתה שר התחבורה או שר ההתנחלויות? כל המדינה תקועה בפקק ואתה בונה עוד כביש בשטחים? כסף לפח
#  הגיע הזמן לשר תחבורה שעובד בשבילנו  true:  NitzanHorowitz predicted:  yairlapid
#
# ברוכה הבאה ג׳ידא רינאוויזועבי, לוחמת אמיתית לשיוויון, לצדק חברתי, ולשותפות  true:  NitzanHorowitz predicted:  ayelet__shaked
#
# נפגשתי עם גורמים אמריקאים בכירים והבהרתי להם שהסיפוח הוא אסון לישראל ואסון לאזור במקביל למאבק הפוליטי שלנו והמערכה על דעת הקהל בישראל, אני מתכוון להמשיך להיפגש עם דיפלומטים ונציגים בינלאומיים כדי לעצור את הסיפוח ולמנוע מהממשלה לקבור את הסיכוי לשלום true:  NitzanHorowitz predicted:  netanyahu
#
# אף בנאדם רציני לא צריך להגיד ״אמרנו לכם״  לא משמאל ולא מימין זה נבוב ומיותר מה שצריך זה לנסות לשנות את המצב, ולא רק ״לנהל את הסכסוך״ true:  NitzanHorowitz predicted:  yairlapid
#
# ״לא באנו לעסוק בבעיות המשפטיות של נתניהו״  חברים, מעולם לא היה שם שום דבר אחר לא בקורונה, ולא לפני הקורונה כבר שנתיים שכל הטירוף הפוליטי במדינה נובע מהשחיתות של נתניהו ומי שחשב שהמשבר הבריאותי והכלכלי העצום ישנה משהו  פשוט לא מבין עם מי יש לו עסק  true:  NitzanHorowitz predicted:  yairlapid
#
# מחזק את אילן גילאון, חבר ונשמה, במאבק למען חוק קצבאות הנכות שהוא מוביל מה שקרה היום בכנסת והמון קשיים אחרים נובעים מכך שאין לנכים ארגון יציג אחד הריב בין שלל הארגונים הוא בלתי נסבל הפיצול הזה הרסני ומקל על הממשלה להמשיך בהתעמרות
#  true:  NitzanHorowitz predicted:  yairlapid
#
# גם מכפר המכביה אני עוקב בהתרגשות אחר ההתחלה היום של רישום זוגות מהקהילה הגאה ובכלל זוגות בעיריית תל אביב  לראשונה בישראל יוזמה של חברי הטוב איתי פנקס, ממרצ כמובן והנה הוא עם בן זוגו יואב ארד וראש העיר רון חולדאי
# חברים, זו מהפיכה
# כל הכבוד וחודש גאווה שמח!  true:  NitzanHorowitz predicted:  regev_miri
#
# אנרגיות חזקות בהתנעת מטה הבחירות המשותף בירושלים כל יום אנחנו בעיר אחרת והשטח שלנו מאושר מהחיבור
# העבודהגשרמרצ!  true:  NitzanHorowitz predicted:  naftalibennett
#
# פה נמצא הכסף הגדול בקומבינות ממוסדות, בעיוותים ״חוקיים״ זו השיטה ולנו מוכרים שלמשרד הבריאות אין  מיליון שקל למניעת התאבדויות, ולמשרד הרווחה אין  מיליון להוסטל לאוטיסטים
# אז אנחנו נמשיך לשלם עשרות אחוזים מס על הכנסות מעבודה, והקרנות האלה יקבלו פטור! על גלגול הון צדק  true:  NitzanHorowitz predicted:  yairlapid
#
# איילון דרום, בדרך לפגוש את העיתונות, ואחר כך בלפור!  true:  NitzanHorowitz predicted:  regev_miri
#
# קללת הפיצול הרעה החולה של הפוליטיקה הישראלית true:  NitzanHorowitz predicted:  regev_miri
#
# אופיר פינס, לשעבר מזכ״ל מפלגת העבודה ושר הפנים, צודק  true:  NitzanHorowitz predicted:  regev_miri
#
# אין ימין, אין שמאל יש רק ביבי
#
# מעריץ את ביבי  יהודי טוב
# מתנגד לביבי  אנטישמי
#
# מה היינו עושים בלעדיו  איך היינו מבחינים בין טוב ורע בעולמנו? true:  NitzanHorowitz predicted:  yairlapid
#
# הכי חשוב כעת לתת מענה לתושבים ולחתור להפסקת אש
# עיתוי הפעולה בעייתי מאוד ברגע ההכרעה על הקמת ממשלה, כשנתניהו נלחם על הישרדותו הפוליטית, כל החלטה שלו, כשאין בידיו מנדט, חשודה באופן בלתי נמנע בניגוד אינטרסים ישראל זקוקה לראש ממשלה במשרה מלאה שלא נתון ללחצים משפטיים ופוליטיים true:  NitzanHorowitz predicted:  yairlapid
#
# זו התעללות בציבור לא יתכן שבמשבר כזה שרים ופקידים סותרים אחד את השני, מוסרים הודעות הפוכות, ומטריפים את העם משפחות של ילדים עם צרכים מיוחדים הן במצב קשה אי אפשר לשחק בהם ככה יש גם מורות, עובדים, מטפלים לאנשים יש חיים צריך גורם אחד, אחד, שיודיע באופן מוסמך ולהפסיק את הבלגן  true:  NitzanHorowitz predicted:  yairlapid
#
# אפס במנהיגות true:  NitzanHorowitz predicted:  regev_miri
#
# שוברים שתיקה ומחסום ווטש לא פועלים נגד חיילי צה״ל, אלא בעדם בעד שיפסיקו לעשות משימות שיטור על אוכלוסייה אזרחית, בעד שיפסיקו לעצור ילדים, בעד סיום הכיבוש
# תלמידים שמבקרים בחברון חייבים לשמוע את האמת על מה שמתרחש שם ורפי פרץ? שוב הוא מראה שאין לו מושג מה זה דמוקרטיה  true:  NitzanHorowitz predicted:  tamarzandberg
#
# לא, זה לא סמל בודהיסטי עתיק בהפגנות האלימות בארה״ב  true:  NitzanHorowitz predicted:  yairlapid
#
# מאפיה  true:  NitzanHorowitz predicted:  regev_miri
#
# עכשיו בכנסת שומרים על ספירת המעטפות הכפולות  true:  NitzanHorowitz predicted:  tamarzandberg
#
# הימין משתולל איך אנחנו מעיזים להטיל ספק במניעי הפעולה, והנה ביבי בעצמו מבקש למסור ״הודעה מיוחדת״ בכנסת כולם נוהרים למליאה והוא עולה לדוכן ועושה סיבוב מתריס, שכולו פוליטיקה קטנה ועלובה, שמבוסס כמה מפתיע על הסתה נגד השמאל והערבים ואז יורד עם חיוך מרוח על פניו זהו,ההצגה הצליחה true:  NitzanHorowitz predicted:  tamarzandberg
#
# צריך ואפשר להקים ״ממשלת משימה״ כל הפרטים  הערב אצל אופירה וברקו  true:  NitzanHorowitz predicted:  naftalibennett
#
# חשוב פורסם עכשיו   זה המועד לדיון בעתירת מרצ ואחרים נגד חוק הלאום למרות התנגדות שרי המשפטים שקד ואוחנה שטענו כי לבגצ אין סמכות לדון נגד חוק יסוד, הדיון יתקיים בהרכב מורחב  או  הכולל כמעט את כל השופטים המכהנים, וגם נקבע מועד קרוב יחסית, למרות בקשות הדחיה של המדינה true:  NitzanHorowitz predicted:  tamarzandberg
#
# מו״מ עם נתניהו? על מה בדיוק? על שוחד, מירמה והפרת אמונים? נתניהו לא ראוי להיות ראש ממשלה נקודה
# האיש הזה הגיש דף ריק ! כעיקרי הטיעונים שלו לשימוע וגנץ נותן לו חבל הצלה? הרי הסיבה העיקרית להצבעה לכחוללבן היתה להחליף את ביבי אל תתנו לו לנצח עכשיו יש אופציה לממשלה אחרת true:  NitzanHorowitz predicted:  yairlapid
#
# נוהרים !  true:  NitzanHorowitz predicted:  regev_miri
#
# ביביגנץ מנצלים את שעותיו האחרונות של נשיא לא לגיטימי, כדי לבצע מחטף ולהרחיב עוד יותר את ההתנחלויות המבודדות בשטחים זו קבלת פנים הרסנית לנשיא החדש ביידן
#  בנייה התנחלויות היא פגיעה אנושה בסיכוי להפרד לשתי מדינות ומקרבת את ישראל והפלסטינים למציאות בלתי הפיכה של מדינה דו לאומית true:  NitzanHorowitz predicted:  naftalibennett
#
# סוף סוף אישה בראש אחת משלוש הגדולות true:  NitzanHorowitz predicted:  ayelet__shaked
#
# מערכת הבחירות מתנהלת כבר שבועיים, הכל סוער ורוגש, אבל על מה? בינתיים היחידה  שמדברת אידיאולוגיה ומציגה חזון מדיני ברור זו
# אפשר להסכים או לא אבל לפחות היא שמה את הדבר הכי חשוב על השולחן true:  NitzanHorowitz predicted:  tamarzandberg
#
# יום שישי השחור, חורף, גשם  במקום להתרוצץ בחוץ ולזרוק כסף על דברים שלא צריך, אפשר להאזין בנחת לפרק החדש בפודקאסט שלי על הנושא הכי חם עכשיו תחבורה עירונית  בגובה העיניים  true:  NitzanHorowitz predicted:  naftalibennett
#
# לכל לוכדי העריקים, מפיצי השמועות ומלבי הסכסוכים  הגעתם לכתובת הלא נכונה חפשו את מזלכם ברשימה אחרת
# ומה כן? בדיוק כמו שאמרנו בקמפיין  אנחנו רוצים להחליף את נתניהו בממשלה בראשות גנץ ואנחנו בתוכה איננו פוסלים שום קבוצה ושום מיגזר
# נביא שינוי ותקווה לישראל
# שבת שלום לכולם true:  NitzanHorowitz predicted:  yairlapid
#
# כניעת נתניהו להנהגה החרדית המופקרת מובילה את ישראל לסגר שלישי פתיחת מוסדות החינוך החרדיים בסתירה מוצהרת לכללי הבריאות ובניגוד מוחלט למוסדות החינוך הכלליים ולחוק, היא סכנה ודאית לבריאות ולכלכלה של המדינה כולה מאות ישראלים, ובראשם החרדים, ישלמו בחייהם, ומאות אלפים ישלמו בפרנסתם true:  NitzanHorowitz predicted:  naftalibennett
#
# צודקת  true:  NitzanHorowitz predicted:  ayelet__shaked
#
# ״הקול להצלת הדמוקרטיה״  יהושע סובול מסביר למה מרצ המון תודה חבר  true:  NitzanHorowitz predicted:  tamarzandberg
#
# קבלו סרטון של קמפיין השיוויון שלנו
# מתנצל מראש שאין פקקים ובקבוקים  true:  NitzanHorowitz predicted:  regev_miri
#
# מפגן עוצמה מרשים בעליה לירושלים, לאורך קילומטרים רבים
# מושחת, לך!  true:  NitzanHorowitz predicted:  regev_miri
#
# איזו תמונה! ראיתי אותה היום ובדקתי השנה   בן גוריון  מ׳ מעניק דרגות קצונה בבה״ד  לחניך המצטיין משה לוי  מ׳, ״משה וחצי״, לימים הרמטכ״ל
# היום יום השנה לפטירתו, ז״ל  true:  NitzanHorowitz predicted:  regev_miri
#
# ״שלום תל אביב!״  השורה התחתונה של האירוויזיון המנצח הזה מיתוג מעולה true:  NitzanHorowitz predicted:  regev_miri
#
# מה מעמד נתניהו היום? ב מול בוז׳י הקים ממשלה בסוף ׳ פיזור הכנסת והפך ר״מ מעבר באפריל ׳ בחירות קיבל את המנדט, כשל בהקמת ממשלה ביוני שוב פיזור כנסת, הוא ממשיך כר״מ של מעבר כפול בספט׳ בחירות, שוב מקבל מנדט ועדיין לא מצליח זה לא ״ר״מ יוצאמעבר״ זה שלטון על כרעי תרנגולת true:  NitzanHorowitz predicted:  yairlapid
#
# הליכודשים  לא עובד אנשים מצביעים ליכוד בגלל מה שהוא אם יחשדו שמתחפש  לא יצביעו לו עדיף להשקיע את המאמץ בחיזוק השמאל ולא להיכנע מראש true:  NitzanHorowitz predicted:  yairlapid
#
# נו חבר, דער קאָראָנאַ ווירוס איז א גוי, פארשטייט נישט יידיש  true:  NitzanHorowitz predicted:  regev_miri
#
# צעירה ״תומכת חרם״ באה לישראל, ללמוד באוניברסיטה העברית בירושלים
# סלקטורים יקרים מהשב״כ, לא נראה לכם שיש פה סתירה? מי שתומך בחרם על ישראל לא בא ללמוד ולגור בה true:  NitzanHorowitz predicted:  yairlapid
#
# לידיעת הח״כים החרדים והם יודעים העבודות הגדולות מחר ברכבת מתבצעות כל כמה חודשים, ואגב בכל שבת יש עבודות תחזוקה גם בהרבה מערכות אחרות הממשלה הזו, כמו כל אחת לפניה ואחריה, ״מחללת״ שבת לא רוצים להיות אחראים? שבו באופוזיציה הצחקתי אתכם? ברור true:  NitzanHorowitz predicted:  yairlapid
#
# אמחייה!  true:  NitzanHorowitz predicted:  regev_miri
#
# נתניהו שגה כשחתם על הצהרה מפורטת כל כך עם פולין בעניין אירועים שהתרחשו בשואה הוא לא היסטוריון, וכל זה לא בתחום מומחיותו וגם לא מתפקידו יש שם מסקנות שנמצאות בוויכוח אפילו בפולין ההודעה החריגה של יד ושם  המוסד הישראלי המוסמך  לא מאפשרת התחמקות הממשלה תהיה חייבת לבטל את ההסכם true:  NitzanHorowitz predicted:  yairlapid

# %%
inverse_dict={count_vectorizer.vocabulary_[w]:w for w in count_vectorizer.vocabulary_.keys()}

# %%
def get_strongest_words(label):
    cur_coef=pipe["algo"].coef_[label]
    word_df=pd.DataFrame({"val":cur_coef}).reset_index().sort_values(["val"],ascending=[False])
    word_df.loc[:, "word"]=word_df["index"].apply(lambda v:inverse_dict[v])
    print(word_df.head(10))

# %%
# AvigdorLiberman 
get_strongest_words(0)
# Out:
#          index       val         word
# 34996    34996  4.450905        ביתנו
# 184394  184394  3.367093       ליברמן
# 259886  259886  3.162597          צהל
# 157158  157158  3.150485  ישראל ביתנו
# 73186    73186  2.163661         החוץ
# 14692    14692  1.970748     אני מברך
# 183094  183094  1.635898        לחמאס
# 109813  109813  1.582707        התורה
# 75084    75084  1.572439      החרדיות
# 42843    42843  1.462276         בעזה

# %%
# NitzanHorowitz
get_strongest_words(1)
# Out:
#          index       val     word
# 246596  246596  2.217054    עכשיו
# 162034  162034  2.167006  כחוללבן
# 200736  200736  1.766627     מאוד
# 81402    81402  1.700697      הכי
# 105521  105521  1.687245      הרי
# 94960    94960  1.665667   הסיפוח
# 70904    70904  1.646539  הורוביץ
# 71293    71293  1.642361      הזה
# 116373  116373  1.627023      וגם
# 254283  254283  1.608142       פה

# %%
# ayelet__shaked
get_strongest_words(2)
# Out:
#          index       val         word
# 214172  214172  2.889500         מיטל
# 91614    91614  2.643003      המשפטים
# 63607    63607  2.100587  הבית היהודי
# 278972  278972  1.903367       שופטים
# 91386    91386  1.681511        המשפט
# 77332    77332  1.652427       היהודי
# 36009    36009  1.600445         בכנס
# 79098    79098  1.455480        הייתה
# 153704  153704  1.440720         ימין
# 107094  107094  1.426454        השופט

# %%
# meravmichaelijs
get_strongest_words(3)
# Out:
#          index       val              word
# 17102    17102  4.898873        ארגוןמוביל
# 17196    17196  3.630111  ארגוןממשלתימוביל
# 102781  102781  3.201272            הקולגה
# 167312  167312  2.703191              כשאת
# 16929    16929  2.614313          אקספלורר
# 241945  241945  2.544505     סמוטיזהאדיוטי
# 22288    22288  2.372504               באג
# 262815  262815  2.335025               קוד
# 22326    22326  2.280844             באגים
# 22059    22059  2.220974               אתן

# %%
# naftalibennett
get_strongest_words(4)
# Out:
#          index       val        word
# 220565  220565  4.054742   מסעהפרנסה
# 259741  259741  2.394524          צה
# 153816  153816  2.371707       ימינה
# 200630  200630  2.271359         מאד
# 26368    26368  2.218075      בדיקות
# 166973  166973  2.148294        כרגע
# 263570  263570  1.927885      קורונה
# 102957  102957  1.867843     הקורונה
# 10526    10526  1.781967          אך
# 79550    79550  1.714463  הימין החדש

# %%
# netanyahu
get_strongest_words(5)
# Out:
#          index       val         word
# 194567  194567  2.086787         לפיד
# 5642      5642  2.004834  אזרחי ישראל
# 74092    74092  1.981347     החיסונים
# 186151  186151  1.963259       לכולכם
# 180446  180446  1.829232       להתחסן
# 280636  280636  1.749778     שידור חי
# 143288  143288  1.645924      חיסונים
# 278407  278407  1.596058       שוחחתי
# 102957  102957  1.543181      הקורונה
# 151840  151840  1.536077          יחד

# %%
# regev_miri 
get_strongest_words(6)
# Out:
#          index       val        word
# 258781  258781  3.006244        פרשת
# 62347    62347  2.868460       הבוקר
# 290154  290154  2.635753        שמחה
# 287066  287066  2.484057  שלום ישראל
# 106685  106685  2.303057        השבת
# 203397  203397  2.057421       מברכת
# 111704  111704  1.955428      התרבות
# 14693    14693  1.939618   אני מברכת
# 95383    95383  1.843079      הספורט
# 215242  215242  1.801821        מירי

# %%
# tamarzandberg
get_strongest_words(7)
# Out:
#          index       val        word
# 226420  226420  2.973854         מרצ
# 48536    48536  2.365609       בשוחד
# 114987  114987  2.342107        ובכן
# 11902    11902  1.936309      אלימות
# 238174  238174  1.615421        נשים
# 241518  241518  1.565498       סיפוח
# 574        574  1.491398         אבל
# 159660  159660  1.486593        כבוד
# 231432  231432  1.455697  נאשם בשוחד
# 304211  304211  1.443168       תרמתי

# %%
# yairlapid
get_strongest_words(8)
# Out:
#          index       val     word
# 31855    31855  2.763262     ביבי
# 203382  203382  2.686660     מברך
# 219216  219216  2.541953  מנותקים
# 295351  295351  2.481212    שפויה
# 203385  203385  2.384511  מברך את
# 62845    62845  2.287509   הבטחון
# 238822  238822  2.279320   נתניהו
# 217992  217992  1.882696    ממשלה
# 156467  156467  1.794635  יש עתיד
# 97737    97737  1.759138  העצמאים

# %% [markdown]
# # Keras
# ## We tried to use NN, results werent good so we moved on to BERT - DONT RUN

# %%
import pandas
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from keras.utils import np_utils
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline

# %%
# encode class values as integers
encoder = LabelEncoder()
encoder.fit(y_train["label"])
encoded_Y = encoder.transform(y_train["label"])

# %%
# convert integers to dummy variables (i.e. one hot encoded)
dummy_y = np_utils.to_categorical(encoded_Y)
print(dummy_y.shape)
# Out:
# (15439, 9)

# %%
encoder.fit(y_test["label"])
encoded_Y_test = encoder.transform(y_test["label"])
dummy_y_test = np_utils.to_categorical(encoded_Y_test)
print(dummy_y_test.shape)
# Out:
# (3860, 9)

# %%
def baseline_model():
	# create model
	model = Sequential()
	model.add(Dense(8, input_dim=200, activation='relu'))
	model.add(Dense(9, activation='softmax'))
	# Compile model
	model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model

# %%
estimator = KerasClassifier(build_fn=baseline_model, epochs=200, batch_size=5, verbose=0)

# %%
kfold = KFold(n_splits=10, shuffle=True)

# %%
print(x_train["text"])
# Out:
# 18708    אום אל פאחם מדוע שוב התוצאה של הפגנה נגד הפשע ...
# 15134    הסכמי השלום ההיסטוריים שהבאנו מתקדמים במהירות ...
# 14332    ממשלה שגורמת לאזרחים שלה לעבור על החוק בלית בר...
# 8486     היום השתתפתי בהפגנה ב״חץ השחור״ שבה מציינים את...
# 6612                              רק שלא נתעורר מאוחר מדי
#                                ...
# 11284    חוזרת למשרד מלאת אנדרנלין אחרי יום מדהים בוינג...
# 11964    מחר, בכנסת, יש לנו הזדמנות לעשות היסטוריה ישרא...
# 5390     אם הליכוד יהיה גדול, תקום ממשלת שמאל רק ימינה ...
# 860      תודה לכל הנשים המדהימות שהגיעו לרוץ איתנו היום...
# 15795    אני לא מכירה צורה כזו של פרוק מונוליט ל  , אך ...
# Name: text, Length: 15439, dtype: object

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer()
tokenizer.fit_on_texts(x_train["text"])

X_train = tokenizer.texts_to_sequences(x_train["text"])
X_test = tokenizer.texts_to_sequences(x_test["text"])

vocab_size = len(tokenizer.word_index) + 1

maxlen = 200

x_train_tok = pad_sequences(X_train, padding='post', maxlen=maxlen)
x_test_tok = pad_sequences(X_test, padding='post', maxlen=maxlen)

print(x_train_tok.shape)
# Out:
# (15439, 200)

# %%
x_train_tokens = pd.DataFrame(columns=["text"])
x_train_tokens["text"] = x_train_tok.tolist()

x_test_tokens = pd.DataFrame(columns=["text"])
x_test_tokens["text"] = x_test_tok.tolist()

y_train_vec = pd.DataFrame(columns=["label"])
y_train_vec["label"] = dummy_y.tolist()

y_test_vec = pd.DataFrame(columns=["label"])
y_test_vec["label"] = dummy_y_test.tolist()
# Out:
# (15439, 1)
# (15439, 1)

# %%
results = cross_val_score(estimator, x_train_tok, dummy_y, cv=kfold)

# %%
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Baseline: 15.80% (0.94%)

# %% [markdown]
# # Keras - with hebrew trained model for word2vec
# ## We tried to use NN with hebrew model, results werent good so we moved on to BERT - DONT RUN

# %%
from numpy import array
from keras.preprocessing.text import one_hot
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers.core import Activation, Dropout, Dense
from keras.layers import Flatten, LSTM
from keras.layers import GlobalMaxPooling1D
from keras.models import Model
from keras.layers.embeddings import Embedding
from sklearn.model_selection import train_test_split
from keras.preprocessing.text import Tokenizer
from keras.layers import Input
from keras.layers.merge import Concatenate

import pandas as pd
import numpy as np
import re

import matplotlib.pyplot as plt
import zipfile
import gensim
from numpy import array
from numpy import asarray
from numpy import zeros
# Out:
# D:\Users\yelfs\AppData\Local\Programs\Python\Python36\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
nlpl_zip="./47.zip"
with zipfile.ZipFile(nlpl_zip, "r") as archive:
    stream = archive.open("model.bin")
    word_vectors = gensim.models.KeyedVectors.load_word2vec_format(stream, binary=True, unicode_errors='replace')

# %%
embedding_matrix = zeros((vocab_size, 100))
skip_counter = 0
for word, index in tokenizer.word_index.items():
    print("index: " + str(index) + " of " + str(vocab_size))
    strip_word = word.strip()
    if strip_word != '':
        try:
            embedding_vector = word_vectors.get_vector(strip_word)
            if embedding_vector is not None:
                embedding_matrix[index] = embedding_vector
        except:
            print("SKIPPING " + word)
            skip_counter += 1
            continue
print("SKIPPED " + str(skip_counter))
# Out:
# ING מנדבך
# index: 55579 of 56269
# index: 55580 of 56269
# index: 55581 of 56269
# index: 55582 of 56269
# index: 55583 of 56269
# SKIPPING לשברו
# index: 55584 of 56269
# SKIPPING להכנת
# index: 55585 of 56269
# SKIPPING והתערבות
# index: 55586 of 56269
# SKIPPING קרעימארק
# index: 55587 of 56269
# SKIPPING בשליחותו
# index: 55588 of 56269
# SKIPPING לשליטה
# index: 55589 of 56269
# index: 55590 of 56269
# SKIPPING באמצעותו
# index: 55591 of 56269
# index: 55592 of 56269
# index: 55593 of 56269
# SKIPPING שעורכים
# index: 55594 of 56269
# index: 55595 of 56269
# index: 55596 of 56269
# index: 55597 of 56269
# index: 55598 of 56269
# SKIPPING גאונים
# index: 55599 of 56269
# SKIPPING והסוחרים
# index: 55600 of 56269
# index: 55601 of 56269
# index: 55602 of 56269
# index: 55603 of 56269
# index: 55604 of 56269
# SKIPPING והפיטפוטים
# index: 55605 of 56269
# index: 55606 of 56269
# SKIPPING ברמדאן
# index: 55607 of 56269
# SKIPPING يشرفني
# index: 55608 of 56269
# SKIPPING باسمي
# index: 55609 of 56269
# SKIPPING وباسم
# index: 55610 of 56269
# SKIPPING وكوادره
# index: 55611 of 56269
# SKIPPING التقدم
# index: 55612 of 56269
# SKIPPING باحر
# index: 55613 of 56269
# SKIPPING التهاني
# index: 55614 of 56269
# SKIPPING والتبريكات
# index: 55615 of 56269
# SKIPPING للمسلمين
# index: 55616 of 56269
# SKIPPING شهر
# index: 55617 of 56269
# SKIPPING يعاد
# index: 55618 of 56269
# SKIPPING לחינוך״
# index: 55619 of 56269
# index: 55620 of 56269
# SKIPPING בחינוך״
# index: 55621 of 56269
# index: 55622 of 56269
# SKIPPING ובבסיסה
# index: 55623 of 56269
# SKIPPING מהשומרון
# index: 55624 of 56269
# index: 55625 of 56269
# index: 55626 of 56269
# SKIPPING ובהכנסותיהם
# index: 55627 of 56269
# index: 55628 of 56269
# index: 55629 of 56269
# index: 55630 of 56269
# SKIPPING למהנדסות
# index: 55631 of 56269
# SKIPPING התוכנות
# index: 55632 of 56269
# SKIPPING שנשותיו
# index: 55633 of 56269
# SKIPPING הנבערות
# index: 55634 of 56269
# index: 55635 of 56269
# index: 55636 of 56269
# SKIPPING הקאוור
# index: 55637 of 56269
# SKIPPING ובחודשיים
# index: 55638 of 56269
# SKIPPING מגופולי
# index: 55639 of 56269
# index: 55640 of 56269
# index: 55641 of 56269
# SKIPPING ״כשזה
# index: 55642 of 56269
# SKIPPING לשתוק״
# index: 55643 of 56269
# index: 55644 of 56269
# index: 55645 of 56269
# SKIPPING לזליונים
# index: 55646 of 56269
# SKIPPING זנאים
embedding_layer = Embedding(vocab_size, 100, weights=[embedding_matrix], trainable=False)(deep_inputs)
LSTM_Layer_1 = LSTM(128)(embedding_layer)
dense_layer_1 = Dense(9, activation='sigmoid')(LSTM_Layer_1)
model = Model(inputs=deep_inputs, outputs=dense_layer_1)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 200)]             0
# _________________________________________________________________
# embedding (Embedding)        (None, 200, 100)          5626900
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               117248
# _________________________________________________________________
# dense_20 (Dense)             (None, 9)                 1161
# =================================================================
# Total params: 5,745,309
# Trainable params: 118,409
# Non-trainable params: 5,626,900
# _________________________________________________________________
# None

# %%
encoded_y_vec = []
for label in encoded_Y:
    y_rep = [0, 0, 0, 0, 0, 0, 0, 0, 0]
    y_rep[label - 1] = 1
    encoded_y_vec.append(y_rep)
encoded_y_vec = np.array(encoded_y_vec)

# %%
print(x_train_tok)
# Out:
# [[ 5908   113  8773 ...     0     0     0]
#  [ 3571   501 12901 ...     0     0     0]
#  [   29 12902  1475 ...     0     0     0]
#  ...
#  [   22    90   110 ...     0     0     0]
#  [   84    58   956 ...     0     0     0]
#  [    9     4  2739 ...     0     0     0]]

# %%
history = model.fit(x_train_tok, encoded_y_vec, batch_size=128, epochs=5, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/5
# 97/97 [==============================] - 28s 286ms/step - loss: 0.3813 - acc: 0.1427 - val_loss: 0.3467 - val_acc: 0.1597
# Epoch 2/5
# 97/97 [==============================] - 28s 289ms/step - loss: 0.3476 - acc: 0.1477 - val_loss: 0.3478 - val_acc: 0.1367
# Epoch 3/5
# 97/97 [==============================] - 28s 289ms/step - loss: 0.3474 - acc: 0.1503 - val_loss: 0.3468 - val_acc: 0.1597
# Epoch 4/5
# 97/97 [==============================] - 29s 300ms/step - loss: 0.3474 - acc: 0.1539 - val_loss: 0.3468 - val_acc: 0.1597
# Epoch 5/5
# 97/97 [==============================] - 29s 300ms/step - loss: 0.3473 - acc: 0.1563 - val_loss: 0.3470 - val_acc: 0.1597

# %%
print(x_train.shape)
# Out:
# (15439, 3)

# %%
from keras.layers import SpatialDropout1D

# The maximum number of words to be used. (most frequent)
MAX_NB_WORDS = 50000
# Max number of words in each complaint.
MAX_SEQUENCE_LENGTH = 250
# This is fixed.
EMBEDDING_DIM = 100

model = Sequential()
model.add(Embedding(vocab_size, EMBEDDING_DIM, input_length=200))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(9, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

epochs = 5
batch_size = 64

# %%
history = model.fit(x_train_tok, encoded_y_vec, epochs=epochs, batch_size=batch_size,validation_split=0.1)
# Out:
# Epoch 1/5
# 218/218 [==============================] - 110s 505ms/step - loss: 2.1831 - accuracy: 0.1549 - val_loss: 2.1797 - val_accuracy: 0.1606
# Epoch 2/5
# 218/218 [==============================] - 110s 503ms/step - loss: 2.1820 - accuracy: 0.1575 - val_loss: 2.1795 - val_accuracy: 0.1606
# Epoch 3/5
# 218/218 [==============================] - 111s 511ms/step - loss: 2.1817 - accuracy: 0.1575 - val_loss: 2.1795 - val_accuracy: 0.1606
# Epoch 4/5
# 218/218 [==============================] - 115s 526ms/step - loss: 2.1815 - accuracy: 0.1575 - val_loss: 2.1785 - val_accuracy: 0.1606
# Epoch 5/5
# 218/218 [==============================] - 118s 543ms/step - loss: 2.1812 - accuracy: 0.1575 - val_loss: 2.1788 - val_accuracy: 0.1606
